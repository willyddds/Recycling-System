# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
import pandas as pd
import matplotlib.pyplot as plt

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
# 設置數據生成器
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=45,
    brightness_range=[0.9, 1.1],
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    shear_range=0.1,
)

# 訓練數據生成器
train_generator = train_datagen.flow_from_directory(
    r'E:\Codes\CV train\回收系統dataset\train',  # 替換為您的資料路徑
    target_size=(224,224),
    batch_size=16,
    class_mode='categorical',
)


validation_datagen = ImageDataGenerator(
    rescale=1./255,
)
# 驗證數據生成器
validation_generator = validation_datagen.flow_from_directory(
    r'E:\Codes\CV train\回收系統dataset\TrashBox',
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical',
)
# Out:
# Found 6370 images belonging to 3 classes.
# Found 9394 images belonging to 3 classes.

# %%
# 測試的解凍層數
unfreeze_layers = [-1, -5, -10, -20, -40, -80, "all"]

# 儲存結果
all_results = []

# %%
# 逐步測試不同的解凍層數
for unfreeze in unfreeze_layers:
    print(f"\n==== 測試解凍層數: {unfreeze} ====")
    
    # 加載預訓練模型
    base_model = MobileNetV2(alpha=0.75, weights='imagenet', include_top=False, input_shape=(224, 224, 3))

    # 添加自定義分類層
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(3, activation='softmax')(x) 
    model = Model(inputs=base_model.input, outputs=x)

    # 設定解凍層數
    if unfreeze == "all":
        for layer in base_model.layers:
            layer.trainable = True
    else:
        for layer in base_model.layers[:unfreeze]:  
            layer.trainable = False

    # 編譯模型
    model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # 訓練模型
    # 訓練模型
    history = model.fit(
        train_generator,
        validation_data=validation_generator,
        epochs=10,
        steps_per_epoch=train_generator.samples // 16,
        validation_steps=validation_generator.samples // 16,
    )

    # 紀錄結果
# Out:
# ==== 測試解凍層數: -1 ====
# Epoch 1/10
# 398/398 [==============================] - 101s 244ms/step - loss: 0.3031 - accuracy: 0.8857 - val_loss: 0.7553 - val_accuracy: 0.7112
# Epoch 2/10
# 398/398 [==============================] - 97s 244ms/step - loss: 0.1779 - accuracy: 0.9337 - val_loss: 0.7937 - val_accuracy: 0.7138
# Epoch 3/10
# 398/398 [==============================] - 91s 229ms/step - loss: 0.1434 - accuracy: 0.9492 - val_loss: 0.8581 - val_accuracy: 0.7213
# Epoch 4/10
# 398/398 [==============================] - 89s 224ms/step - loss: 0.1260 - accuracy: 0.9566 - val_loss: 0.8363 - val_accuracy: 0.7185
# Epoch 5/10
# 398/398 [==============================] - 88s 221ms/step - loss: 0.1185 - accuracy: 0.9577 - val_loss: 0.9360 - val_accuracy: 0.7162
# Epoch 6/10
# 398/398 [==============================] - 88s 220ms/step - loss: 0.1075 - accuracy: 0.9643 - val_loss: 0.9732 - val_accuracy: 0.7111
# Epoch 7/10
# 398/398 [==============================] - 89s 224ms/step - loss: 0.1065 - accuracy: 0.9614 - val_loss: 1.0013 - val_accuracy: 0.7191
# Epoch 8/10
# 398/398 [==============================] - 92s 232ms/step - loss: 0.1007 - accuracy: 0.9647 - val_loss: 1.1694 - val_accuracy: 0.6925
# Epoch 9/10
# 398/398 [==============================] - 93s 233ms/step - loss: 0.0913 - accuracy: 0.9676 - val_loss: 0.9491 - val_accuracy: 0.7279
# Epoch 10/10
# 398/398 [==============================] - 87s 220ms/step - loss: 0.0870 - accuracy: 0.9679 - val_loss: 1.0746 - val_accuracy: 0.7140
#
# ==== 測試解凍層數: -5 ====
# Epoch 1/10
# 398/398 [==============================] - 90s 220ms/step - loss: 0.2813 - accuracy: 0.8963 - val_loss: 9.0256 - val_accuracy: 0.4124
# Epoch 2/10
# 398/398 [==============================] - 87s 219ms/step - loss: 0.1984 - accuracy: 0.9256 - val_loss: 14.1636 - val_accuracy: 0.3990
# Epoch 3/10
# 398/398 [==============================] - 88s 221ms/step - loss: 0.1943 - accuracy: 0.9320 - val_loss: 5.6603 - val_accuracy: 0.5302
# Epoch 4/10
# 398/398 [==============================] - 89s 224ms/step - loss: 0.1771 - accuracy: 0.9356 - val_loss: 9.7828 - val_accuracy: 0.4553
# Epoch 5/10
# 398/398 [==============================] - 88s 222ms/step - loss: 0.1556 - accuracy: 0.9452 - val_loss: 3.8135 - val_accuracy: 0.5972
# Epoch 6/10
# 398/398 [==============================] - 90s 225ms/step - loss: 0.1409 - accuracy: 0.9520 - val_loss: 2.7476 - val_accuracy: 0.6469
# Epoch 7/10
# 398/398 [==============================] - 89s 223ms/step - loss: 0.0999 - accuracy: 0.9638 - val_loss: 2.3398 - val_accuracy: 0.6738
# Epoch 8/10
# 398/398 [==============================] - 90s 227ms/step - loss: 0.1191 - accuracy: 0.9567 - val_loss: 1.6862 - val_accuracy: 0.7099
# Epoch 9/10
# 398/398 [==============================] - 91s 228ms/step - loss: 0.0995 - accuracy: 0.9630 - val_loss: 2.1498 - val_accuracy: 0.6953
# Epoch 10/10
# 398/398 [==============================] - 90s 227ms/step - loss: 0.1059 - accuracy: 0.9619 - val_loss: 2.0347 - val_accuracy: 0.6876
#
# ==== 測試解凍層數: -10 ====
# Epoch 1/10
# 398/398 [==============================] - 93s 229ms/step - loss: 0.2836 - accuracy: 0.8941 - val_loss: 3.3473 - val_accuracy: 0.6301
# Epoch 2/10
# 398/398 [==============================] - 89s 224ms/step - loss: 0.2038 - accuracy: 0.9260 - val_loss: 5.2525 - val_accuracy: 0.5289
# Epoch 3/10
# 398/398 [==============================] - 90s 225ms/step - loss: 0.1768 - accuracy: 0.9330 - val_loss: 3.8595 - val_accuracy: 0.5463
# Epoch 4/10
# 398/398 [==============================] - 90s 225ms/step - loss: 0.1395 - accuracy: 0.9501 - val_loss: 4.2782 - val_accuracy: 0.5548
# Epoch 5/10
# 398/398 [==============================] - 87s 219ms/step - loss: 0.1243 - accuracy: 0.9539 - val_loss: 1.8640 - val_accuracy: 0.7238
# Epoch 6/10
# 398/398 [==============================] - 87s 218ms/step - loss: 0.1188 - accuracy: 0.9556 - val_loss: 2.3674 - val_accuracy: 0.6659
# Epoch 7/10
# 398/398 [==============================] - 88s 221ms/step - loss: 0.1037 - accuracy: 0.9629 - val_loss: 2.4953 - val_accuracy: 0.6835
# Epoch 8/10
# 398/398 [==============================] - 88s 221ms/step - loss: 0.1006 - accuracy: 0.9633 - val_loss: 1.9540 - val_accuracy: 0.7050
# Epoch 9/10
# 398/398 [==============================] - 89s 224ms/step - loss: 0.1030 - accuracy: 0.9636 - val_loss: 1.9886 - val_accuracy: 0.7118
# Epoch 10/10
# 398/398 [==============================] - 89s 224ms/step - loss: 0.0881 - accuracy: 0.9668 - val_loss: 2.3629 - val_accuracy: 0.6928
#
# ==== 測試解凍層數: -20 ====
# Epoch 1/10
# 398/398 [==============================] - 91s 223ms/step - loss: 0.2744 - accuracy: 0.8968 - val_loss: 5.0508 - val_accuracy: 0.6422
# Epoch 2/10
# 398/398 [==============================] - 87s 219ms/step - loss: 0.1690 - accuracy: 0.9364 - val_loss: 3.7670 - val_accuracy: 0.6816
# Epoch 3/10
# 398/398 [==============================] - 88s 221ms/step - loss: 0.1323 - accuracy: 0.9522 - val_loss: 2.9568 - val_accuracy: 0.6813
# Epoch 4/10
# 398/398 [==============================] - 88s 222ms/step - loss: 0.1110 - accuracy: 0.9605 - val_loss: 3.3738 - val_accuracy: 0.6601
# Epoch 5/10
# 398/398 [==============================] - 89s 224ms/step - loss: 0.1071 - accuracy: 0.9619 - val_loss: 3.1270 - val_accuracy: 0.6697
# Epoch 6/10
# 398/398 [==============================] - 86s 217ms/step - loss: 0.0865 - accuracy: 0.9662 - val_loss: 2.1869 - val_accuracy: 0.7050
# Epoch 7/10
# 398/398 [==============================] - 89s 223ms/step - loss: 0.0776 - accuracy: 0.9714 - val_loss: 4.5838 - val_accuracy: 0.6707
# Epoch 8/10
# 398/398 [==============================] - 87s 219ms/step - loss: 0.0690 - accuracy: 0.9761 - val_loss: 3.0782 - val_accuracy: 0.6886
# Epoch 9/10
# 398/398 [==============================] - 88s 221ms/step - loss: 0.0778 - accuracy: 0.9706 - val_loss: 3.6626 - val_accuracy: 0.6479
# Epoch 10/10
# 398/398 [==============================] - 88s 221ms/step - loss: 0.0545 - accuracy: 0.9791 - val_loss: 4.9779 - val_accuracy: 0.5717
#
# ==== 測試解凍層數: -40 ====
# Epoch 1/10
# 398/398 [==============================] - 89s 220ms/step - loss: 0.3067 - accuracy: 0.8835 - val_loss: 7.4480 - val_accuracy: 0.4042
# Epoch 2/10
# 398/398 [==============================] - 87s 219ms/step - loss: 0.1735 - accuracy: 0.9393 - val_loss: 4.5643 - val_accuracy: 0.4148
# Epoch 3/10
# 398/398 [==============================] - 87s 219ms/step - loss: 0.1406 - accuracy: 0.9473 - val_loss: 6.0538 - val_accuracy: 0.4610
# Epoch 4/10
# 398/398 [==============================] - 87s 218ms/step - loss: 0.1270 - accuracy: 0.9539 - val_loss: 4.2313 - val_accuracy: 0.6140
# Epoch 5/10
# 398/398 [==============================] - 87s 218ms/step - loss: 0.1183 - accuracy: 0.9578 - val_loss: 7.8805 - val_accuracy: 0.4029
# Epoch 6/10
# 398/398 [==============================] - 87s 219ms/step - loss: 0.1195 - accuracy: 0.9585 - val_loss: 4.8470 - val_accuracy: 0.5221
# Epoch 7/10
# 398/398 [==============================] - 87s 218ms/step - loss: 0.1165 - accuracy: 0.9592 - val_loss: 3.1172 - val_accuracy: 0.6268
# Epoch 8/10
# 398/398 [==============================] - 87s 218ms/step - loss: 0.0998 - accuracy: 0.9649 - val_loss: 3.4250 - val_accuracy: 0.5875
# Epoch 9/10
# 398/398 [==============================] - 86s 217ms/step - loss: 0.0909 - accuracy: 0.9706 - val_loss: 5.3301 - val_accuracy: 0.5975
# Epoch 10/10
# 398/398 [==============================] - 87s 220ms/step - loss: 0.0668 - accuracy: 0.9783 - val_loss: 5.7538 - val_accuracy: 0.5694
#
# ==== 測試解凍層數: -80 ====
# Epoch 1/10
# 398/398 [==============================] - 93s 228ms/step - loss: 0.3562 - accuracy: 0.8709 - val_loss: 8.2760 - val_accuracy: 0.5013
# Epoch 2/10
# 398/398 [==============================] - 89s 223ms/step - loss: 0.2109 - accuracy: 0.9199 - val_loss: 5.2450 - val_accuracy: 0.4070
# Epoch 3/10
# 398/398 [==============================] - 88s 221ms/step - loss: 0.1984 - accuracy: 0.9268 - val_loss: 4.3013 - val_accuracy: 0.5227
# Epoch 4/10
# 398/398 [==============================] - 89s 224ms/step - loss: 0.1624 - accuracy: 0.9408 - val_loss: 4.9486 - val_accuracy: 0.4056
# Epoch 5/10
# 398/398 [==============================] - 89s 223ms/step - loss: 0.1457 - accuracy: 0.9424 - val_loss: 4.4701 - val_accuracy: 0.4725
# Epoch 6/10
# 398/398 [==============================] - 89s 223ms/step - loss: 0.1392 - accuracy: 0.9492 - val_loss: 3.6684 - val_accuracy: 0.4618
# Epoch 7/10
# 398/398 [==============================] - 89s 223ms/step - loss: 0.1131 - accuracy: 0.9583 - val_loss: 8.1410 - val_accuracy: 0.4185
# Epoch 8/10
# 398/398 [==============================] - 89s 224ms/step - loss: 0.1049 - accuracy: 0.9630 - val_loss: 6.5051 - val_accuracy: 0.4995
# Epoch 9/10
# 398/398 [==============================] - 90s 225ms/step - loss: 0.0941 - accuracy: 0.9671 - val_loss: 4.6803 - val_accuracy: 0.5429
# Epoch 10/10
# 398/398 [==============================] - 88s 222ms/step - loss: 0.0842 - accuracy: 0.9684 - val_loss: 4.8766 - val_accuracy: 0.5194
#
# ==== 測試解凍層數: all ====
# Epoch 1/10
# 398/398 [==============================] - 93s 225ms/step - loss: 0.3718 - accuracy: 0.8573 - val_loss: 18.5688 - val_accuracy: 0.3964
# Epoch 2/10
# 398/398 [==============================] - 89s 224ms/step - loss: 0.2424 - accuracy: 0.9057 - val_loss: 13.1155 - val_accuracy: 0.2942
# Epoch 3/10
# 398/398 [==============================] - 89s 223ms/step - loss: 0.2249 - accuracy: 0.9174 - val_loss: 13.1489 - val_accuracy: 0.1754
# Epoch 4/10
# 398/398 [==============================] - 89s 224ms/step - loss: 0.1823 - accuracy: 0.9309 - val_loss: 12.2351 - val_accuracy: 0.1743
# Epoch 5/10
# 398/398 [==============================] - 89s 223ms/step - loss: 0.1762 - accuracy: 0.9361 - val_loss: 12.5564 - val_accuracy: 0.1839
# Epoch 6/10
# 398/398 [==============================] - 89s 224ms/step - loss: 0.2156 - accuracy: 0.9196 - val_loss: 9.7231 - val_accuracy: 0.3086
# Epoch 7/10
# 398/398 [==============================] - 89s 225ms/step - loss: 0.1769 - accuracy: 0.9339 - val_loss: 11.1659 - val_accuracy: 0.2472
# Epoch 8/10
# 398/398 [==============================] - 89s 224ms/step - loss: 0.1577 - accuracy: 0.9402 - val_loss: 6.8150 - val_accuracy: 0.3351
# Epoch 9/10
# 398/398 [==============================] - 89s 225ms/step - loss: 0.1297 - accuracy: 0.9518 - val_loss: 5.8396 - val_accuracy: 0.4275
# Epoch 10/10
# 398/398 [==============================] - 89s 224ms/step - loss: 0.1186 - accuracy: 0.9589 - val_loss: 5.5065 - val_accuracy: 0.4371
